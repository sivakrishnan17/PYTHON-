# %%
from CLASS_2 import All_in_One as a

# %%
a.find()
# Out:
# Enter a number : 14
# 14 is Even number
# 'Even'

# %%
a.formula()
# Out:
# enter height 1 : 14
# enter breath of the triangle : 20
# Enter which formula ('area(a)' or 'perimeter(p)' a
# Area is : 140.0.
# 140.0

# %%
a.elegible()
# Out:
# Enter your gender : male
# Enter your age : 21
# Eligible for marrige

# %%
# a=All_in_One()
a.percentage(100,100,100,100,100)
# Out:
# subject_1=100
# subject_2=100
# subject_3=100
# subject_4=100
# subject_5=100
#
# Percentage : 100.0%

# %%
a.Subfields()
# Out:
# Sub-fields in AI are :
# ML
# Neural Networks
# Vision
# Robotics
# Speech Processing
# NLP
