# %% [markdown]
# @ question 1 :

# %%
print("Hope AI")
# Out:
# Hope AI

# %% [markdown]
# @ question 2:

# %%
name=input("Enter your institute name? :")
# Out:
# Enter your institute name? : Hope AI

# %% [markdown]
# @ question 3:

# %%
name=input("Enter your name :")
age=int(input("Enter your age :"))
school=input("Enter your school :")
degree=input("Enter your degree :")
# Out:
# Enter your name : siva
# Enter your age : 21
# Enter your school : abcd
# Enter your degree : b.Tech

# %% [markdown]
# @ question 4:

# %%
# add
a=10
b=20
add=a+b
print(f"a={a}\nb={b}\nadd={add}")
# Out:
# a=10
# b=20
# add=30

# %%
# sub
a=10
b=20
sub=a-b
print(f"a={a}\nb={b}\nsub={sub}")
# Out:
# a=10
# b=20
# add=-10

# %%
# Mul
a=10
b=20
mul=a*b
print(f"a={a}\nb={b}\nmul={mul}")
# Out:
# a=10
# b=20
# mul=200

# %%
# div
a=10
b=20
div=a/b
print(f"a={a}\nb={b}\ndiv={div}")
# Out:
# a=10
# b=20
# div=0.5

# %%
# floor div:
# add
a=40
b=20
f_div=a//b
print(f"a={a}\nb={b}\nfloor_division={f_div}")
# Out:
# a=40
# b=20
# floor_division=2

# %%
# modulo:
a=100
b=20
modulo=a%b
print(f"a={a}\nb={b}\nmadulo={modulo}")
# Out:
# a=100
# b=20
# madulo=0

# %%
# power
a=2
b=5
add=a**b
print(f"a={a}\nb={b}\npower={add}")
# Out:
# a=2
# b=5
# power=32
